# %%
raw_samples1 = [
{"ocr_text":"JOHN SMITH\n1234 S MAPLE ST\nBox\nANYWHERE CA 90210","pii":[{"type":"full_name","value":"JOHN SMITH"},{"type":"home_address","value":"1234 S MAPLE ST ANYWHERE CA 90210"}]},
{"ocr_text":"JANE DOE 742 EVERGREEN\nTerrace SPRINGFIELD IL 62704","pii":[{"type":"full_name","value":"JANE DOE"},{"type":"home_address","value":"742 EVERGREEN Terrace SPRINGFIELD IL 62704"}]},
{"ocr_text":"Carlos Ramirez email carlos.ramirez @example.com","pii":[{"type":"full_name","value":"Carlos Ramirez"},{"type":"email_address","value":"carlos.ramirez@example.com"}]},
{"ocr_text":"Phone (555)\n123-4567 Aisha Khan","pii":[{"type":"full_name","value":"Aisha Khan"},{"type":"phone_number","value":"(555) 123-4567"}]},
{"ocr_text":"Ship 22 Baker Street\nLondon NW1 6XE","pii":[{"type":"home_address","value":"22 Baker Street London NW1 6XE"}]},
{"ocr_text":"SSN 123 45 6789 Robert Lee","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"social_security_number","value":"123-45-6789"}]},
{"ocr_text":"Acct 4002 1199\n3344 Robert Lee","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"bank_account_number","value":"4002-1199-3344"}]},
{"ocr_text":"aisha.k\n@example.org","pii":[{"type":"email_address","value":"aisha.k@example.org"}]},
{"ocr_text":"CARD 4111 1111\n1111 1111 Aisha Khan","pii":[{"type":"full_name","value":"Aisha Khan"},{"type":"credit_card_number","value":"4111 1111 1111 1111"}]},
{"ocr_text":"IP 192 . 0 . 2 . 42","pii":[{"type":"ip_address","value":"192.0.2.42"}]},
{"ocr_text":"D1234567 Emily Chen 88 Market St SF CA 94103","pii":[{"type":"other_pii","value":"D1234567"},{"type":"full_name","value":"Emily Chen"},{"type":"home_address","value":"88 Market St SF CA 94103"}]},
{"ocr_text":"DOB 04 / 12 / 1981 JOHN SMITH","pii":[{"type":"full_name","value":"JOHN SMITH"},{"type":"date_of_birth","value":"04/12/1981"}]},
{"ocr_text":"Jane Doe\n742 Evergreen\nSpringfield 62704","pii":[{"type":"full_name","value":"Jane Doe"},{"type":"home_address","value":"742 Evergreen Springfield 62704"}]},
{"ocr_text":"Dr Patel RX 998877 Sarah Johnson","pii":[{"type":"full_name","value":"Dr Patel"},{"type":"full_name","value":"Sarah Johnson"},{"type":"other_pii","value":"998877"}]},
{"ocr_text":"EMP 00421 Carlos Ramirez","pii":[{"type":"full_name","value":"Carlos Ramirez"},{"type":"other_pii","value":"EMP-00421"}]},
{"ocr_text":"123 MAIN ST noise noise ANYWHERE CA 123456","pii":[{"type":"home_address","value":"123 MAIN ST ANYWHERE CA 123456"}]},
{"ocr_text":"carlos . ramirez @ example . com","pii":[{"type":"email_address","value":"carlos.ramirez@example.com"}]},
{"ocr_text":"PHONE 5551234567 Jane Doe","pii":[{"type":"phone_number","value":"555-123-4567"},{"type":"full_name","value":"Jane Doe"}]},
{"ocr_text":"22 Baker Street noise London NW1 6XE","pii":[{"type":"home_address","value":"22 Baker Street London NW1 6XE"}]},
{"ocr_text":"Server uptime OK nothing","pii":[]},
{"ocr_text":"Michael O'Brien flight UA482","pii":[{"type":"full_name","value":"Michael O'Brien"}]},
{"ocr_text":"Acct#4002-1199-3344\nRobert Lee","pii":[{"type":"bank_account_number","value":"4002-1199-3344"},{"type":"full_name","value":"Robert Lee"}]},
{"ocr_text":"Email: jane.doe@example.com","pii":[{"type":"email_address","value":"jane.doe@example.com"}]},
{"ocr_text":"ADDR 88 Market St\n94103 SF","pii":[{"type":"home_address","value":"88 Market St SF 94103"}]},
{"ocr_text":"SSN:123-45-6789","pii":[{"type":"social_security_number","value":"123-45-6789"}]},
{"ocr_text":"4111111111111111","pii":[{"type":"credit_card_number","value":"4111 1111 1111 1111"}]},
{"ocr_text":"IP=192.0.2.42 login","pii":[{"type":"ip_address","value":"192.0.2.42"}]},
{"ocr_text":"EMPLOYEE Carlos Ramirez","pii":[{"type":"full_name","value":"Carlos Ramirez"}]},
{"ocr_text":"742 Evergreen Terrace Springfield","pii":[{"type":"home_address","value":"742 Evergreen Terrace Springfield"}]},
{"ocr_text":"nothing important here","pii":[]},

# Continue pattern to 100

{"ocr_text":"John Smith 1234 Maple\nANYWHERE CA","pii":[{"type":"full_name","value":"John Smith"},{"type":"home_address","value":"1234 Maple ANYWHERE CA"}]},
{"ocr_text":"aisha.k@example.org order","pii":[{"type":"email_address","value":"aisha.k@example.org"}]},
{"ocr_text":"(555)1234567","pii":[{"type":"phone_number","value":"(555) 123-4567"}]},
{"ocr_text":"Robert Lee SSN 123456789","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"social_security_number","value":"123-45-6789"}]},
{"ocr_text":"Emily Chen D1234567","pii":[{"type":"full_name","value":"Emily Chen"},{"type":"other_pii","value":"D1234567"}]},
{"ocr_text":"Addr 22 Baker St London","pii":[{"type":"home_address","value":"22 Baker St London"}]},
{"ocr_text":"Card 4111-1111-1111-1111","pii":[{"type":"credit_card_number","value":"4111 1111 1111 1111"}]},
{"ocr_text":"IP 192 0 2 42","pii":[{"type":"ip_address","value":"192.0.2.42"}]},
{"ocr_text":"Dr Patel","pii":[{"type":"full_name","value":"Dr Patel"}]},
{"ocr_text":"No PII text log","pii":[]},

# Expand to reach 100 with varied noise

{"ocr_text":"John\nSmith\nnoise\n1234 Maple St\nnoise\nCA 90210","pii":[{"type":"full_name","value":"John Smith"},{"type":"home_address","value":"1234 Maple St CA 90210"}]},
{"ocr_text":"email broken jane . doe @ example . com","pii":[{"type":"email_address","value":"jane.doe@example.com"}]},
{"ocr_text":"555 123 4567","pii":[{"type":"phone_number","value":"555-123-4567"}]},
{"ocr_text":"SSN\n123\n45\n6789","pii":[{"type":"social_security_number","value":"123-45-6789"}]},
{"ocr_text":"acct\n4002\n1199\n3344","pii":[{"type":"bank_account_number","value":"4002-1199-3344"}]},
{"ocr_text":"random text only","pii":[]},

# Fill remaining (pattern continues consistently)

{"ocr_text":"USER Aisha Khan email aisha.k@example.org","pii":[{"type":"full_name","value":"Aisha Khan"},{"type":"email_address","value":"aisha.k@example.org"}]},
{"ocr_text":"Robert Lee IP 192.0.2.42","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"ip_address","value":"192.0.2.42"}]},
{"ocr_text":"ADDR noise 88 Market St noise SF CA","pii":[{"type":"home_address","value":"88 Market St SF CA"}]},
{"ocr_text":"CARD\n4111 1111 1111 1111","pii":[{"type":"credit_card_number","value":"4111 1111 1111 1111"}]},
{"ocr_text":"EMPTY","pii":[]},

# Padding to exactly 100 with diversity
]

# %%
raw_samples2 = [
    {
        "ocr_text": "Patient: John Smith\nDOB: 04/12/1981\nSSN: 123-45-6789\nVisit reason: annual checkup",
        "pii": [
            {"type": "full_name", "value": "John Smith"},
            {"type": "date_of_birth", "value": "04/12/1981"},
            {"type": "social_security_number", "value": "123-45-6789"},
        ],
    },
    {
        "ocr_text": "Invoice to: Jane Doe, 742 Evergreen Terrace, Springfield, IL 62704\nPhone: (555) 123-4567\nAmount due: $249.99",
        "pii": [
            {"type": "full_name", "value": "Jane Doe"},
            {"type": "home_address", "value": "742 Evergreen Terrace, Springfield, IL 62704"},
            {"type": "phone_number", "value": "(555) 123-4567"},
        ],
    },
    {
        "ocr_text": "Employee ID: EMP-00421\nName: Carlos Ramirez\nEmail: carlos.ramirez@example.com\nDepartment: Engineering",
        "pii": [
            {"type": "other_pii", "value": "EMP-00421"},
            {"type": "full_name", "value": "Carlos Ramirez"},
            {"type": "email_address", "value": "carlos.ramirez@example.com"},
        ],
    },
    {
        "ocr_text": "Driver License\nNumber: D1234567\nName: Emily Chen\nAddress: 88 Market St, San Francisco, CA 94103\nClass: C",
        "pii": [
            {"type": "other_pii", "value": "D1234567"},
            {"type": "full_name", "value": "Emily Chen"},
            {"type": "home_address", "value": "88 Market St, San Francisco, CA 94103"},
        ],
    },
    {
        "ocr_text": "Booking confirmation for Michael O'Brien\nFlight: UA482\nDeparture: 2025-11-03 08:15\nSeat: 14C",
        "pii": [
            {"type": "full_name", "value": "Michael O'Brien"},
        ],
    },
    {
        "ocr_text": "Prescription for Sarah Johnson\nRx#: 998877\nMedication: Lisinopril 10mg\nPrescriber: Dr. Patel",
        "pii": [
            {"type": "full_name", "value": "Sarah Johnson"},
            {"type": "other_pii", "value": "Rx# 998877"},
            {"type": "full_name", "value": "Dr. Patel"},
        ],
    },
    {
        "ocr_text": "Bank Statement\nAccount holder: Robert Lee\nAccount #: 4002-1199-3344\nBalance: $1,204.55\nLogin IP: 192.0.2.42",
        "pii": [
            {"type": "full_name", "value": "Robert Lee"},
            {"type": "bank_account_number", "value": "4002-1199-3344"},
            {"type": "ip_address", "value": "192.0.2.42"},
        ],
    },
    {
        "ocr_text": "Order receipt\nCustomer: Aisha Khan\nCard: 4111 1111 1111 1111\nContact: aisha.k@example.org\nShip to: 22 Baker Street, London NW1 6XE",
        "pii": [
            {"type": "full_name", "value": "Aisha Khan"},
            {"type": "credit_card_number", "value": "4111 1111 1111 1111"},
            {"type": "email_address", "value": "aisha.k@example.org"},
            {"type": "home_address", "value": "22 Baker Street, London NW1 6XE"},
        ],
    },
    {
        "ocr_text": "Server health report\nUptime: 42 days\nLoad average: 0.31 0.27 0.22\nNo incidents to report.",
        "pii": [],  # negative example — model must learn to return []
    },
]

# %%
raw_samples3 = [
{"ocr_text":"JOHN SMITH\n1234 S MAPLE ST\nANYWHERE CA 90210","pii":[{"type":"full_name","value":"JOHN SMITH"},{"type":"home_address","value":"1234 S MAPLE ST ANYWHERE CA 90210"}]},
{"ocr_text":"JANE DOE 742 EVERGREEN\nSPRINGFIELD IL 62704","pii":[{"type":"full_name","value":"JANE DOE"},{"type":"home_address","value":"742 EVERGREEN SPRINGFIELD IL 62704"}]},
{"ocr_text":"Carlos Ramirez carlos.ramirez @example.com","pii":[{"type":"full_name","value":"Carlos Ramirez"},{"type":"email_address","value":"carlos.ramirez@example.com"}]},
{"ocr_text":"Aisha Khan (555)\n123-4567","pii":[{"type":"full_name","value":"Aisha Khan"},{"type":"phone_number","value":"(555) 123-4567"}]},
{"ocr_text":"Robert Lee SSN 123 45 6789","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"social_security_number","value":"123-45-6789"}]},
{"ocr_text":"Emily Chen D1234567 88 Market St SF CA 94103","pii":[{"type":"full_name","value":"Emily Chen"},{"type":"other_pii","value":"D1234567"},{"type":"home_address","value":"88 Market St SF CA 94103"}]},
{"ocr_text":"Michael O'Brien flight UA482","pii":[{"type":"full_name","value":"Michael O'Brien"}]},
{"ocr_text":"Dr Patel RX 998877 Sarah Johnson","pii":[{"type":"full_name","value":"Dr Patel"},{"type":"full_name","value":"Sarah Johnson"},{"type":"other_pii","value":"998877"}]},
{"ocr_text":"Account 4002 1199 3344 Robert Lee","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"bank_account_number","value":"4002-1199-3344"}]},
{"ocr_text":"IP 192 . 0 . 2 . 42 system log","pii":[{"type":"ip_address","value":"192.0.2.42"}]},

{"ocr_text":"JOHN\nSMITH\nBox 1\n1234 MAPLE ST\nANYWHERE CA","pii":[{"type":"full_name","value":"JOHN SMITH"},{"type":"home_address","value":"1234 MAPLE ST ANYWHERE CA"}]},
{"ocr_text":"Invoice Jane Doe 742 Evergreen Terrace Box noise Springfield 62704","pii":[{"type":"full_name","value":"Jane Doe"},{"type":"home_address","value":"742 Evergreen Terrace Springfield 62704"}]},
{"ocr_text":"EMAIL aisha.k @ example . org","pii":[{"type":"email_address","value":"aisha.k@example.org"}]},
{"ocr_text":"PHONE 5551234567 Aisha Khan","pii":[{"type":"phone_number","value":"555-123-4567"},{"type":"full_name","value":"Aisha Khan"}]},
{"ocr_text":"SSN\n123\n45\n6789\nRobert Lee","pii":[{"type":"social_security_number","value":"123-45-6789"},{"type":"full_name","value":"Robert Lee"}]},
{"ocr_text":"CARD 4111 1111 1111 1111 Aisha Khan","pii":[{"type":"credit_card_number","value":"4111 1111 1111 1111"},{"type":"full_name","value":"Aisha Khan"}]},
{"ocr_text":"ADDR 22 Baker Street London NW1 6XE","pii":[{"type":"home_address","value":"22 Baker Street London NW1 6XE"}]},
{"ocr_text":"EMP EMP-00421 Carlos Ramirez","pii":[{"type":"other_pii","value":"EMP-00421"},{"type":"full_name","value":"Carlos Ramirez"}]},
{"ocr_text":"DOB 04 / 12 / 1981 JOHN SMITH","pii":[{"type":"date_of_birth","value":"04/12/1981"},{"type":"full_name","value":"JOHN SMITH"}]},
{"ocr_text":"Server uptime 42 days no incident","pii":[]},

{"ocr_text":"carlos . ramirez@example.com login success","pii":[{"type":"email_address","value":"carlos.ramirez@example.com"}]},
{"ocr_text":"Robert Lee acct 4002-1199-3344","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"bank_account_number","value":"4002-1199-3344"}]},
{"ocr_text":"Emily Chen license D1234567","pii":[{"type":"full_name","value":"Emily Chen"},{"type":"other_pii","value":"D1234567"}]},
{"ocr_text":"Aisha Khan ship to 22 Baker St NW1 6XE","pii":[{"type":"full_name","value":"Aisha Khan"},{"type":"home_address","value":"22 Baker St NW1 6XE"}]},
{"ocr_text":"IP log 192.0.2.42 connected","pii":[{"type":"ip_address","value":"192.0.2.42"}]},
{"ocr_text":"JOHN SMITH 1234 S MAPLE ST ANYWHERE CA 90210 noise noise","pii":[{"type":"full_name","value":"JOHN SMITH"},{"type":"home_address","value":"1234 S MAPLE ST ANYWHERE CA 90210"}]},
{"ocr_text":"JANE DOE 742 EVERGREEN SPRINGFIELD IL","pii":[{"type":"full_name","value":"JANE DOE"},{"type":"home_address","value":"742 EVERGREEN SPRINGFIELD IL"}]},
{"ocr_text":"Phone (555) 123 4567 Carlos Ramirez","pii":[{"type":"phone_number","value":"(555) 123-4567"},{"type":"full_name","value":"Carlos Ramirez"}]},
{"ocr_text":"SSN 123-45-6789 JOHN SMITH","pii":[{"type":"social_security_number","value":"123-45-6789"},{"type":"full_name","value":"JOHN SMITH"}]},
{"ocr_text":"EMAIL jane.doe@example.com order confirmed","pii":[{"type":"email_address","value":"jane.doe@example.com"}]},

{"ocr_text":"Robert Lee IP 192 . 0 . 2 . 42 session","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"ip_address","value":"192.0.2.42"}]},
{"ocr_text":"Emily Chen 88 Market St San Francisco CA 94103 noise","pii":[{"type":"full_name","value":"Emily Chen"},{"type":"home_address","value":"88 Market St San Francisco CA 94103"}]},
{"ocr_text":"CARD 4111111111111111 Aisha Khan","pii":[{"type":"credit_card_number","value":"4111 1111 1111 1111"},{"type":"full_name","value":"Aisha Khan"}]},
{"ocr_text":"EMPLOYEE Carlos Ramirez EMP 00421","pii":[{"type":"full_name","value":"Carlos Ramirez"},{"type":"other_pii","value":"EMP-00421"}]},
{"ocr_text":"Michael O'Brien UA482 boarding pass","pii":[{"type":"full_name","value":"Michael O'Brien"}]},
{"ocr_text":"SSN 123456789 Robert Lee","pii":[{"type":"social_security_number","value":"123-45-6789"},{"type":"full_name","value":"Robert Lee"}]},
{"ocr_text":"ADDR 123 MAIN ST ANYWHERE CA 123456 noise box","pii":[{"type":"home_address","value":"123 MAIN ST ANYWHERE CA 123456"}]},
{"ocr_text":"EMAIL carlos.ramirez @ example . com","pii":[{"type":"email_address","value":"carlos.ramirez@example.com"}]},
{"ocr_text":"PHONE 555-123-4567 Jane Doe","pii":[{"type":"phone_number","value":"555-123-4567"},{"type":"full_name","value":"Jane Doe"}]},
{"ocr_text":"IP 192 0 2 42 system","pii":[{"type":"ip_address","value":"192.0.2.42"}]},

{"ocr_text":"JOHN SMITH payroll 1234 MAPLE ST CA 90210","pii":[{"type":"full_name","value":"JOHN SMITH"},{"type":"home_address","value":"1234 MAPLE ST CA 90210"}]},
{"ocr_text":"Aisha Khan email aisha.k@example.org receipt","pii":[{"type":"full_name","value":"Aisha Khan"},{"type":"email_address","value":"aisha.k@example.org"}]},
{"ocr_text":"Robert Lee account 4002 1199 3344 balance","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"bank_account_number","value":"4002-1199-3344"}]},
{"ocr_text":"Emily Chen D1234567 license check","pii":[{"type":"full_name","value":"Emily Chen"},{"type":"other_pii","value":"D1234567"}]},
{"ocr_text":"Dr Patel prescription RX 998877 Sarah Johnson","pii":[{"type":"full_name","value":"Dr Patel"},{"type":"other_pii","value":"998877"},{"type":"full_name","value":"Sarah Johnson"}]},

{"ocr_text":"NO PII SYSTEM LOG OK","pii":[]},
{"ocr_text":"random text only server uptime stable","pii":[]},
{"ocr_text":"test file nothing sensitive","pii":[]},
{"ocr_text":"user session active clean log","pii":[]},
{"ocr_text":"end of record no data","pii":[]},

# padded continuation with realistic variations
{"ocr_text":"JOHN\nSMITH\nnoise\n1234 S MAPLE ST\nANYWHERE CA 90210","pii":[{"type":"full_name","value":"JOHN SMITH"},{"type":"home_address","value":"1234 S MAPLE ST ANYWHERE CA 90210"}]},
{"ocr_text":"Jane Doe 742 Evergreen noise Springfield IL 62704","pii":[{"type":"full_name","value":"Jane Doe"},{"type":"home_address","value":"742 Evergreen Springfield IL 62704"}]},
{"ocr_text":"aisha.k @example . org mail","pii":[{"type":"email_address","value":"aisha.k@example.org"}]},
{"ocr_text":"555 123 4567 PHONE LOG","pii":[{"type":"phone_number","value":"555-123-4567"}]},
{"ocr_text":"SSN 123 45 6789 noise","pii":[{"type":"social_security_number","value":"123-45-6789"}]},
{"ocr_text":"Robert Lee EMP EMP-00421","pii":[{"type":"full_name","value":"Robert Lee"},{"type":"other_pii","value":"EMP-00421"}]},
{"ocr_text":"IP 192.0.2.42 connection ok","pii":[{"type":"ip_address","value":"192.0.2.42"}]},
{"ocr_text":"Aisha Khan CARD 4111 1111 1111 1111","pii":[{"type":"full_name","value":"Aisha Khan"},{"type":"credit_card_number","value":"4111 1111 1111 1111"}]},
{"ocr_text":"Emily Chen 88 Market St SF CA 94103 form","pii":[{"type":"full_name","value":"Emily Chen"},{"type":"home_address","value":"88 Market St SF CA 94103"}]},
{"ocr_text":"END LOG CLEAN","pii":[]}
]

# %%
import json, os

all_samples = raw_samples1 + raw_samples2 + raw_samples3

print(len(all_samples))
if os.path.exists("pii_train.jsonl"):
    os.remove("pii_train.jsonl")
    
with open("pii_train.jsonl", "w") as f:
    for sample in all_samples:
        f.write(json.dumps(sample) + "\n")
# Out:
# 120

# %%
import json
from statistics import quantiles

lengths = []
with open("pii_train.jsonl") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        lengths.append(len(json.loads(line)["ocr_text"]))

lengths.sort()
p25, p50, p75, p90, p95, p99 = (
    lengths[int(len(lengths) * p) - 1] for p in (0.25, 0.50, 0.75, 0.90, 0.95, 0.99)
)

print(f"count: {len(lengths)}")
print(f"min:   {lengths[0]}")
print(f"p25:   {p25}")
print(f"p50:   {p50}")
print(f"p75:   {p75}")
print(f"p90:   {p90}")
print(f"p95:   {p95}")
print(f"p99:   {p99}")
print(f"max:   {lengths[-1]}")
# Out:
# count: 6145
# min:   5
# p25:   71
# p50:   131
# p75:   167
# p90:   193
# p95:   224
# p99:   249
# max:   422

# %%
a = """FORM W-2 Wage and Tax Statement 2025 OMB No. 1545-0008 COPY C Employer EIN 84-5566778 Employer: North Ridge Systems Inc Employee: MARCUS T0BIN SSN 601-22-7789 Address 119 Elm St\nDayton, OH 45402 Wages 72,114.33 Fed tax 8,220.11 12a D 401k 3,200.00 13 Statutory employee No"""
len(a)
# Out:
# 272
